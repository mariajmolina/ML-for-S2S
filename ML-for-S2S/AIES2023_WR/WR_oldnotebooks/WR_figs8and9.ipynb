# %% [markdown]
# # Figures 8-9 and S. Figures 5-8 (Molina et al., in prep.)

# %% [markdown]
# ## Imports

# %%
import numpy as np
import xarray as xr

import matplotlib.pyplot as plt
import matplotlib as mpl
import cartopy
import cartopy.crs as ccrs
import cartopy.feature
import cartopy.feature as cfeature
from shapely import geometry

# %%
mpl.rcParams['hatch.linewidth'] = 0.3

# %% [markdown]
# ## open and preprocess data

# %%
ds_rlut = xr.open_dataset(
    '/glade/scratch/molina/s2s/bootstrap/rlut_week34_wxregimes.nc')
ds_sstk = xr.open_dataset(
    '/glade/scratch/molina/s2s/bootstrap/sstk_week34_wxregimes.nc')

# %% [markdown]
# ## Figure 8

# %%
vmin = -5
vmax = 5

proj = ccrs.PlateCarree(central_longitude=180.0)

lons, lats = np.meshgrid(ds_rlut.lon, ds_rlut.lat)

# ---

fig, axs = plt.subplots(
    4, 2, subplot_kw=dict(projection=proj), figsize=(11, 8))

# ---

pm = axs[0][0].pcolormesh(lons, lats, -ds_rlut["wr1_era5"].values,
                          transform=ccrs.PlateCarree(),
                          vmin=vmin, vmax=vmax, cmap='BrBG_r')

axs[0][0].contourf(lons, lats, np.where((
    -ds_rlut["wr1_era5"].values >= -ds_rlut['wr1_era5_005'].values) | (
    -ds_rlut["wr1_era5"].values <= -ds_rlut['wr1_era5_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[0][0].set_extent([20, 340, -50, 50], crs=ccrs.PlateCarree())

axs[0][0].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[0][0].set_title(
    'a) WR1: Alaskan Ridge (ERA5)', fontsize=12)
axs[0][0].margins(x=0, y=0)

geom = geometry.box(minx=30, maxx=210, miny=-10, maxy=10)

axs[0][0].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='k', lw=2)

geom = geometry.box(minx=170-360, maxx=250-360, miny=10, maxy=48)

axs[0][0].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='b', lw=2)

gl = axs[0][0].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

# ---

axs[0][1].pcolormesh(lons, lats, ds_rlut["wr1_cesm"].values,
                     transform=ccrs.PlateCarree(), 
                     vmin=vmin, vmax=vmax, cmap='BrBG_r')

axs[0][1].contourf(lons, lats, np.where((
    ds_rlut["wr1_cesm"].values <= ds_rlut['wr1_cesm_005'].values) | (
    ds_rlut["wr1_cesm"].values >= ds_rlut['wr1_cesm_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[0][1].set_extent([20, 340, -50, 50], crs=ccrs.PlateCarree())

axs[0][1].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[0][1].set_title(
    'b) WR1: Alaskan Ridge (CESM2)', fontsize=12)
axs[0][1].margins(x=0, y=0)

geom = geometry.box(minx=30, maxx=210, miny=-10, maxy=10)

axs[0][1].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='k', lw=2)

geom = geometry.box(minx=170-360, maxx=250-360, miny=10, maxy=48)

axs[0][1].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='b', lw=2)

gl = axs[0][1].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

# ---

axs[1][0].pcolormesh(lons, lats, -ds_rlut["wr2_era5"].values,
                     transform=ccrs.PlateCarree(),
                     vmin=vmin, vmax=vmax, cmap='BrBG_r')

axs[1][0].contourf(lons, lats, np.where((
    -ds_rlut["wr2_era5"].values >= -ds_rlut['wr2_era5_005'].values) | (
    -ds_rlut["wr2_era5"].values <= -ds_rlut['wr2_era5_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[1][0].set_extent([20, 340, -50, 50], crs=ccrs.PlateCarree())

axs[1][0].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[1][0].set_title(
    'c) WR2: Greenland High (ERA5)', fontsize=12)
axs[1][0].margins(x=0, y=0)

geom = geometry.box(minx=30, maxx=210, miny=-10, maxy=10)

axs[1][0].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='k', lw=2)

geom = geometry.box(minx=170-360, maxx=250-360, miny=10, maxy=48)

axs[1][0].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='b', lw=2)

gl = axs[1][0].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

# ---

axs[1][1].pcolormesh(lons, lats, ds_rlut["wr2_cesm"].values,
                     transform=ccrs.PlateCarree(),
                     vmin=vmin, vmax=vmax, cmap='BrBG_r')

axs[1][1].contourf(lons, lats, np.where((
    ds_rlut["wr2_cesm"].values <= ds_rlut['wr2_cesm_005'].values) | (
    ds_rlut["wr2_cesm"].values >= ds_rlut['wr2_cesm_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[1][1].set_extent([20, 340, -50, 50], crs=ccrs.PlateCarree())

axs[1][1].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[1][1].set_title(
    'd) WR2: Greenland High (CESM2)', fontsize=12)
axs[1][1].margins(x=0, y=0)

geom = geometry.box(minx=30, maxx=210, miny=-10, maxy=10)

axs[1][1].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='k', lw=2)

geom = geometry.box(minx=170-360, maxx=250-360, miny=10, maxy=48)

axs[1][1].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='b', lw=2)

gl = axs[1][1].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

# ---

axs[2][0].pcolormesh(lons, lats, -ds_rlut["wr3_era5"].values,
                     transform=ccrs.PlateCarree(), 
                     vmin=vmin, vmax=vmax, cmap='BrBG_r')

axs[2][0].contourf(lons, lats, np.where((
    -ds_rlut["wr3_era5"].values >= -ds_rlut['wr3_era5_005'].values) | (
    -ds_rlut["wr3_era5"].values <= -ds_rlut['wr3_era5_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[2][0].set_extent([20, 340, -50, 50], crs=ccrs.PlateCarree())

axs[2][0].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[2][0].set_title(
    'e) WR3: Pacific Trough (ERA5)', fontsize=12)
axs[2][0].margins(x=0, y=0)

geom = geometry.box(minx=30, maxx=210, miny=-10, maxy=10)

axs[2][0].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='k', lw=2)

geom = geometry.box(minx=170-360, maxx=250-360, miny=10, maxy=48)

axs[2][0].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='b', lw=2)

gl = axs[2][0].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

# ---

axs[2][1].pcolormesh(lons, lats, ds_rlut["wr3_cesm"].values,
                     transform=ccrs.PlateCarree(),
                     vmin=vmin, vmax=vmax, cmap='BrBG_r')

axs[2][1].contourf(lons, lats, np.where((
    ds_rlut["wr3_cesm"].values <= ds_rlut['wr3_cesm_005'].values) | (
    ds_rlut["wr3_cesm"].values >= ds_rlut['wr3_cesm_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[2][1].set_extent([20, 340, -50, 50], crs=ccrs.PlateCarree())

axs[2][1].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[2][1].set_title(
    'f) WR3: Pacific Trough (CESM2)', fontsize=12)
axs[2][1].margins(x=0, y=0)

geom = geometry.box(minx=30, maxx=210, miny=-10, maxy=10)

axs[2][1].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='k', lw=2)

geom = geometry.box(minx=170-360, maxx=250-360, miny=10, maxy=48)

axs[2][1].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='b', lw=2)

gl = axs[2][1].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

# ---

axs[3][0].pcolormesh(lons, lats, -ds_rlut["wr4_era5"].values,
                     transform=ccrs.PlateCarree(),
                     vmin=vmin, vmax=vmax, cmap='BrBG_r')

axs[3][0].contourf(lons, lats, np.where((
    -ds_rlut["wr4_era5"].values >= -ds_rlut['wr4_era5_005'].values) | (
    -ds_rlut["wr4_era5"].values <= -ds_rlut['wr4_era5_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[3][0].set_extent([20, 340, -50, 50], crs=ccrs.PlateCarree())

axs[3][0].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[3][0].set_title(
    'g) WR4: West Coast High (ERA5)', fontsize=12)
axs[3][0].margins(x=0,y=0)

geom = geometry.box(minx=30, maxx=210, miny=-10, maxy=10)

axs[3][0].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='k', lw=2)

geom = geometry.box(minx=170-360, maxx=250-360, miny=10, maxy=48)

axs[3][0].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='b', lw=2)

gl = axs[3][0].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

# ---

axs[3][1].pcolormesh(lons, lats, ds_rlut["wr4_cesm"].values,
                     transform=ccrs.PlateCarree(),
                     vmin=vmin, vmax=vmax, cmap='BrBG_r')

axs[3][1].contourf(lons, lats, np.where((
    ds_rlut["wr4_cesm"].values <= ds_rlut['wr4_cesm_005'].values) | (
    ds_rlut["wr4_cesm"].values >= ds_rlut['wr4_cesm_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[3][1].set_extent([20, 340, -50, 50], crs=ccrs.PlateCarree())

axs[3][1].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[3][1].set_title(
    'h) WR4: West Coast High (CESM2)', fontsize=12)
axs[3][1].margins(x=0, y=0)

geom = geometry.box(minx=30, maxx=210, miny=-10, maxy=10)

axs[3][1].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='k', lw=2)

geom = geometry.box(minx=170-360, maxx=250-360, miny=10, maxy=48)

axs[3][1].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='b', lw=2)

gl = axs[3][1].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

# ---

cbar_ax = fig.add_axes([0.25, -0.01, 0.5, 0.015])

ticks_1 = [-4, -2, 0, 2, 4]
cbar = fig.colorbar(pm, cax=cbar_ax, ticks=ticks_1[:],
                    orientation='horizontal', extend='both')

cbar.ax.tick_params(labelsize=12)
cbar.set_label(
    u'Weeks 3-4 Outgoing Longwave Radiation (W m$^{-2}$)', fontsize=12)

# --

plt.tight_layout()
plt.savefig("fig_wk34_olr.png", bbox_inches='tight', dpi=500)
plt.show()

# ---
# Out:
# /glade/scratch/molina/ipykernel_17828/90025266.py:339: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# ## Figure 9

# %%
vmin = -0.5
vmax = 0.5

proj = ccrs.PlateCarree(central_longitude=180.0)

lons, lats = np.meshgrid(ds_sstk.lon, ds_sstk.lat)

# ---

fig, axs = plt.subplots(
    4, 2, subplot_kw=dict(projection=proj), figsize=(11, 8))

# ---

pm = axs[0][0].pcolormesh(lons, lats, ds_sstk["wr1_era5"].values,
                          transform=ccrs.PlateCarree(),
                          vmin=vmin, vmax=vmax, cmap='seismic')

axs[0][0].contourf(lons, lats, np.where((
    ds_sstk["wr1_era5"].values <= ds_sstk['wr1_era5_005'].values) | (
    ds_sstk["wr1_era5"].values >= ds_sstk['wr1_era5_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[0][0].set_extent([20, 340, -30, 70], crs=ccrs.PlateCarree())

axs[0][0].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[0][0].add_feature(cfeature.LAND, color='k', zorder=100)
axs[0][0].set_title('a) WR1: Alaskan Ridge (ERA5)', fontsize=12)
axs[0][0].margins(x=0, y=0)

gl = axs[0][0].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

geom = geometry.box(minx=120, maxx=280, miny=-10, maxy=10)
# 10°S-10°N and 120°E-80°W
axs[0][0].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='dimgrey', lw=2.)

# ---

axs[0][1].pcolormesh(lons, lats, ds_sstk["wr1_cesm"].values,
                     transform=ccrs.PlateCarree(),
                     vmin=vmin, vmax=vmax, cmap='seismic')

axs[0][1].contourf(lons, lats, np.where((
    ds_sstk["wr1_cesm"].values <= ds_sstk['wr1_cesm_005'].values) | (
    ds_sstk["wr1_cesm"].values >= ds_sstk['wr1_cesm_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[0][1].set_extent([20, 340, -30, 70], crs=ccrs.PlateCarree())

axs[0][1].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[0][1].add_feature(cfeature.LAND, color='k', zorder=100)
axs[0][1].set_title('b) WR1: Alaskan Ridge (CESM2)', fontsize=12)
axs[0][1].margins(x=0, y=0)

gl = axs[0][1].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

geom = geometry.box(minx=120, maxx=280, miny=-10, maxy=10)

axs[0][1].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='dimgrey', lw=2.)

# ---

axs[1][0].pcolormesh(lons, lats, ds_sstk["wr2_era5"].values, 
                     transform=ccrs.PlateCarree(), 
                     vmin=vmin, vmax=vmax, cmap='seismic')

axs[1][0].contourf(lons, lats, np.where((
    ds_sstk["wr2_era5"].values <= ds_sstk['wr2_era5_005'].values) | (
    ds_sstk["wr2_era5"].values >= ds_sstk['wr2_era5_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[1][0].set_extent([20, 340, -30, 70], crs=ccrs.PlateCarree())

axs[1][0].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[1][0].add_feature(cfeature.LAND, color='k', zorder=100)
axs[1][0].set_title('c) WR2: Greenland High (ERA5)', fontsize=12)
axs[1][0].margins(x=0, y=0)

gl = axs[1][0].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

geom = geometry.box(minx=120, maxx=280, miny=-10, maxy=10)

axs[1][0].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='dimgrey', lw=2.)

# ---

axs[1][1].pcolormesh(lons, lats, ds_sstk["wr2_cesm"].values,
                     transform=ccrs.PlateCarree(),
                     vmin=vmin, vmax=vmax, cmap='seismic')

axs[1][1].contourf(lons, lats, np.where((
    ds_sstk["wr2_cesm"].values <= ds_sstk['wr2_cesm_005'].values) | (
    ds_sstk["wr2_cesm"].values >= ds_sstk['wr2_cesm_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[1][1].set_extent([20, 340, -30, 70], crs=ccrs.PlateCarree())

axs[1][1].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[1][1].add_feature(cfeature.LAND, color='k', zorder=100)
axs[1][1].set_title('d) WR2: Greenland High (CESM2)', fontsize=12)
axs[1][1].margins(x=0, y=0)

gl = axs[1][1].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

geom = geometry.box(minx=120, maxx=280, miny=-10, maxy=10)

axs[1][1].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='dimgrey', lw=2.)

# ---

axs[2][0].pcolormesh(lons, lats, ds_sstk["wr3_era5"].values,
                     transform=ccrs.PlateCarree(),
                     vmin=vmin, vmax=vmax, cmap='seismic')

axs[2][0].contourf(lons, lats, np.where((
    ds_sstk["wr3_era5"].values <= ds_sstk['wr3_era5_005'].values) | (
    ds_sstk["wr3_era5"].values >= ds_sstk['wr3_era5_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[2][0].set_extent([20, 340, -30, 70], crs=ccrs.PlateCarree())

axs[2][0].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[2][0].add_feature(cfeature.LAND, color='k', zorder=100)
axs[2][0].set_title('e) WR3: Pacific Trough (ERA5)', fontsize=12)
axs[2][0].margins(x=0, y=0)

gl = axs[2][0].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

geom = geometry.box(minx=120, maxx=280, miny=-10, maxy=10)

axs[2][0].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='dimgrey', lw=2.)

# ---

axs[2][1].pcolormesh(lons, lats, ds_sstk["wr3_cesm"].values,
                     transform=ccrs.PlateCarree(),
                     vmin=vmin, vmax=vmax, cmap='seismic')

axs[2][1].contourf(lons, lats, np.where((
    ds_sstk["wr3_cesm"].values <= ds_sstk['wr3_cesm_005'].values) | (
    ds_sstk["wr3_cesm"].values >= ds_sstk['wr3_cesm_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[2][1].set_extent([20, 340, -30, 70], crs=ccrs.PlateCarree())

axs[2][1].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[2][1].add_feature(cfeature.LAND, color='k', zorder=100)
axs[2][1].set_title('f) WR3: Pacific Trough (CESM2)', fontsize=12)
axs[2][1].margins(x=0, y=0)

gl = axs[2][1].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

geom = geometry.box(minx=120, maxx=280, miny=-10, maxy=10)

axs[2][1].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='dimgrey', lw=2.)

# ---

axs[3][0].pcolormesh(lons, lats, ds_sstk["wr4_era5"].values,
                     transform=ccrs.PlateCarree(),
                     vmin=vmin, vmax=vmax, cmap='seismic')

axs[3][0].contourf(lons, lats, np.where((
    ds_sstk["wr4_era5"].values <= ds_sstk['wr4_era5_005'].values) | (
    ds_sstk["wr4_era5"].values >= ds_sstk['wr4_era5_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[3][0].set_extent([20, 340, -30, 70], crs=ccrs.PlateCarree())

axs[3][0].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[3][0].add_feature(cfeature.LAND, color='k', zorder=100)
axs[3][0].set_title(
    'g) WR4: West Coast High (ERA5)', fontsize=12)
axs[3][0].margins(x=0, y=0)

gl = axs[3][0].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

geom = geometry.box(minx=120, maxx=280, miny=-10, maxy=10)

axs[3][0].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='dimgrey', lw=2.)

# ---

axs[3][1].pcolormesh(lons, lats, ds_sstk["wr4_cesm"].values,
                     transform=ccrs.PlateCarree(),
                     vmin=vmin, vmax=vmax, cmap='seismic')

axs[3][1].contourf(lons, lats, np.where((
    ds_sstk["wr4_cesm"].values <= ds_sstk['wr4_cesm_005'].values) | (
    ds_sstk["wr4_cesm"].values >= ds_sstk['wr4_cesm_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[3][1].set_extent([20, 340, -30, 70], crs=ccrs.PlateCarree())

axs[3][1].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[3][1].add_feature(cfeature.LAND, color='k', zorder=100)
axs[3][1].set_title('h) WR4: West Coast High (CESM2)', fontsize=12)
axs[3][1].margins(x=0, y=0)

gl = axs[3][1].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

geom = geometry.box(minx=120, maxx=280, miny=-10, maxy=10)

axs[3][1].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='dimgrey', lw=2.)

# ---

cbar_ax = fig.add_axes([0.25, -0.01, 0.5, 0.015])

ticks_1 = [-0.5, -0.25, 0, 0.25, 0.5]
cbar = fig.colorbar(pm, cax=cbar_ax, ticks=ticks_1[:],
                    orientation='horizontal', extend='both')

cbar.ax.tick_params(labelsize=12)
cbar.set_label(u'Weeks 3-4 SST ($^{\circ}$C)', fontsize=12)

# --

plt.tight_layout()
plt.savefig("fig_wk34_sst.png", bbox_inches='tight', dpi=500)
plt.show()

# ---
# Out:
# /glade/scratch/molina/ipykernel_17828/1774812598.py:299: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# ## open data

# %%
ds_rlut = xr.open_dataset(
    '/glade/scratch/molina/s2s/bootstrap/rlut_week12_wxregimes.nc')
ds_sstk = xr.open_dataset(
    '/glade/scratch/molina/s2s/bootstrap/sstk_week12_wxregimes.nc')

# %% [markdown]
# ## Supplementary Figure 5

# %%
vmin = -5
vmax = 5

proj = ccrs.PlateCarree(central_longitude=180.0)

lons, lats = np.meshgrid(ds_rlut.lon, ds_rlut.lat)

# ---

fig, axs = plt.subplots(
    4, 2, subplot_kw=dict(projection=proj), figsize=(11, 8))

# ---

pm = axs[0][0].pcolormesh(lons, lats, -ds_rlut["wr1_era5"].values,
                          transform=ccrs.PlateCarree(),
                          vmin=vmin, vmax=vmax, cmap='BrBG_r')

axs[0][0].contourf(lons, lats, np.where((
    -ds_rlut["wr1_era5"].values >= -ds_rlut['wr1_era5_005'].values) | (
    -ds_rlut["wr1_era5"].values <= -ds_rlut['wr1_era5_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[0][0].set_extent([20, 340, -50, 50], crs=ccrs.PlateCarree())

axs[0][0].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[0][0].set_title(
    'a) WR1: Alaskan Ridge (ERA5)', fontsize=12)
axs[0][0].margins(x=0, y=0)

geom = geometry.box(minx=30, maxx=210, miny=-10, maxy=10)

axs[0][0].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='k', lw=2)

geom = geometry.box(minx=170-360, maxx=250-360, miny=10, maxy=48)

axs[0][0].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='b', lw=2)

gl = axs[0][0].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

# ---

axs[0][1].pcolormesh(lons, lats, ds_rlut["wr1_cesm"].values,
                     transform=ccrs.PlateCarree(), 
                     vmin=vmin, vmax=vmax, cmap='BrBG_r')

axs[0][1].contourf(lons, lats, np.where((
    ds_rlut["wr1_cesm"].values <= ds_rlut['wr1_cesm_005'].values) | (
    ds_rlut["wr1_cesm"].values >= ds_rlut['wr1_cesm_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[0][1].set_extent([20, 340, -50, 50], crs=ccrs.PlateCarree())

axs[0][1].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[0][1].set_title(
    'b) WR1: Alaskan Ridge (CESM2)', fontsize=12)
axs[0][1].margins(x=0, y=0)

geom = geometry.box(minx=30, maxx=210, miny=-10, maxy=10)

axs[0][1].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='k', lw=2)

geom = geometry.box(minx=170-360, maxx=250-360, miny=10, maxy=48)

axs[0][1].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='b', lw=2)

gl = axs[0][1].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

# ---

axs[1][0].pcolormesh(lons, lats, -ds_rlut["wr2_era5"].values,
                     transform=ccrs.PlateCarree(),
                     vmin=vmin, vmax=vmax, cmap='BrBG_r')

axs[1][0].contourf(lons, lats, np.where((
    -ds_rlut["wr2_era5"].values >= -ds_rlut['wr2_era5_005'].values) | (
    -ds_rlut["wr2_era5"].values <= -ds_rlut['wr2_era5_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[1][0].set_extent([20, 340, -50, 50], crs=ccrs.PlateCarree())

axs[1][0].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[1][0].set_title(
    'c) WR2: Greenland High (ERA5)', fontsize=12)
axs[1][0].margins(x=0, y=0)

geom = geometry.box(minx=30, maxx=210, miny=-10, maxy=10)

axs[1][0].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='k', lw=2)

geom = geometry.box(minx=170-360, maxx=250-360, miny=10, maxy=48)

axs[1][0].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='b', lw=2)

gl = axs[1][0].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

# ---

axs[1][1].pcolormesh(lons, lats, ds_rlut["wr2_cesm"].values,
                     transform=ccrs.PlateCarree(),
                     vmin=vmin, vmax=vmax, cmap='BrBG_r')

axs[1][1].contourf(lons, lats, np.where((
    ds_rlut["wr2_cesm"].values <= ds_rlut['wr2_cesm_005'].values) | (
    ds_rlut["wr2_cesm"].values >= ds_rlut['wr2_cesm_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[1][1].set_extent([20, 340, -50, 50], crs=ccrs.PlateCarree())

axs[1][1].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[1][1].set_title(
    'd) WR2: Greenland High (CESM2)', fontsize=12)
axs[1][1].margins(x=0, y=0)

geom = geometry.box(minx=30, maxx=210, miny=-10, maxy=10)

axs[1][1].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='k', lw=2)

geom = geometry.box(minx=170-360, maxx=250-360, miny=10, maxy=48)

axs[1][1].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='b', lw=2)

gl = axs[1][1].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

# ---

axs[2][0].pcolormesh(lons, lats, -ds_rlut["wr3_era5"].values,
                     transform=ccrs.PlateCarree(), 
                     vmin=vmin, vmax=vmax, cmap='BrBG_r')

axs[2][0].contourf(lons, lats, np.where((
    -ds_rlut["wr3_era5"].values >= -ds_rlut['wr3_era5_005'].values) | (
    -ds_rlut["wr3_era5"].values <= -ds_rlut['wr3_era5_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[2][0].set_extent([20, 340, -50, 50], crs=ccrs.PlateCarree())

axs[2][0].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[2][0].set_title(
    'e) WR3: Pacific Trough (ERA5)', fontsize=12)
axs[2][0].margins(x=0, y=0)

geom = geometry.box(minx=30, maxx=210, miny=-10, maxy=10)

axs[2][0].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='k', lw=2)

geom = geometry.box(minx=170-360, maxx=250-360, miny=10, maxy=48)

axs[2][0].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='b', lw=2)

gl = axs[2][0].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

# ---

axs[2][1].pcolormesh(lons, lats, ds_rlut["wr3_cesm"].values,
                     transform=ccrs.PlateCarree(),
                     vmin=vmin, vmax=vmax, cmap='BrBG_r')

axs[2][1].contourf(lons, lats, np.where((
    ds_rlut["wr3_cesm"].values <= ds_rlut['wr3_cesm_005'].values) | (
    ds_rlut["wr3_cesm"].values >= ds_rlut['wr3_cesm_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[2][1].set_extent([20, 340, -50, 50], crs=ccrs.PlateCarree())

axs[2][1].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[2][1].set_title(
    'f) WR3: Pacific Trough (CESM2)', fontsize=12)
axs[2][1].margins(x=0, y=0)

geom = geometry.box(minx=30, maxx=210, miny=-10, maxy=10)

axs[2][1].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='k', lw=2)

geom = geometry.box(minx=170-360, maxx=250-360, miny=10, maxy=48)

axs[2][1].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='b', lw=2)

gl = axs[2][1].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

# ---

axs[3][0].pcolormesh(lons, lats, -ds_rlut["wr4_era5"].values,
                     transform=ccrs.PlateCarree(),
                     vmin=vmin, vmax=vmax, cmap='BrBG_r')

axs[3][0].contourf(lons, lats, np.where((
    -ds_rlut["wr4_era5"].values >= -ds_rlut['wr4_era5_005'].values) | (
    -ds_rlut["wr4_era5"].values <= -ds_rlut['wr4_era5_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[3][0].set_extent([20, 340, -50, 50], crs=ccrs.PlateCarree())

axs[3][0].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[3][0].set_title(
    'g) WR4: West Coast High (ERA5)', fontsize=12)
axs[3][0].margins(x=0,y=0)

geom = geometry.box(minx=30, maxx=210, miny=-10, maxy=10)

axs[3][0].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='k', lw=2)

geom = geometry.box(minx=170-360, maxx=250-360, miny=10, maxy=48)

axs[3][0].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='b', lw=2)

gl = axs[3][0].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

# ---

axs[3][1].pcolormesh(lons, lats, ds_rlut["wr4_cesm"].values,
                     transform=ccrs.PlateCarree(),
                     vmin=vmin, vmax=vmax, cmap='BrBG_r')

axs[3][1].contourf(lons, lats, np.where((
    ds_rlut["wr4_cesm"].values <= ds_rlut['wr4_cesm_005'].values) | (
    ds_rlut["wr4_cesm"].values >= ds_rlut['wr4_cesm_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[3][1].set_extent([20, 340, -50, 50], crs=ccrs.PlateCarree())

axs[3][1].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[3][1].set_title(
    'h) WR4: West Coast High (CESM2)', fontsize=12)
axs[3][1].margins(x=0, y=0)

geom = geometry.box(minx=30, maxx=210, miny=-10, maxy=10)

axs[3][1].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='k', lw=2)

geom = geometry.box(minx=170-360, maxx=250-360, miny=10, maxy=48)

axs[3][1].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='b', lw=2)

gl = axs[3][1].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

# ---

cbar_ax = fig.add_axes([0.25, -0.01, 0.5, 0.015])

ticks_1 = [-4, -2, 0, 2, 4]
cbar = fig.colorbar(pm, cax=cbar_ax, ticks=ticks_1[:], 
                    orientation='horizontal', extend='both')

cbar.ax.tick_params(labelsize=12)
cbar.set_label(u'Weeks 1-2 Outgoing Longwave Radiation (W m$^{-2}$)', fontsize=12)

# --

plt.tight_layout()
plt.savefig("fig_wk12_olr.png", bbox_inches='tight', dpi=500)
plt.show()

# ---
# Out:
# /glade/scratch/molina/ipykernel_17828/4200143647.py:338: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# ## Supplementary Figure 6

# %%
vmin = -0.5
vmax = 0.5

proj = ccrs.PlateCarree(central_longitude=180.0)

lons, lats = np.meshgrid(ds_sstk.lon, ds_sstk.lat)

# ---

fig, axs = plt.subplots(
    4, 2, subplot_kw=dict(projection=proj), figsize=(11, 8))

# ---

pm = axs[0][0].pcolormesh(lons, lats, ds_sstk["wr1_era5"].values,
                          transform=ccrs.PlateCarree(),
                          vmin=vmin, vmax=vmax, cmap='seismic')

axs[0][0].contourf(lons, lats, np.where((
    ds_sstk["wr1_era5"].values <= ds_sstk['wr1_era5_005'].values) | (
    ds_sstk["wr1_era5"].values >= ds_sstk['wr1_era5_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[0][0].set_extent([20, 340, -30, 70], crs=ccrs.PlateCarree())

axs[0][0].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[0][0].add_feature(cfeature.LAND, color='k', zorder=100)
axs[0][0].set_title('a) WR1: Alaskan Ridge (ERA5)', fontsize=12)
axs[0][0].margins(x=0, y=0)

gl = axs[0][0].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

geom = geometry.box(minx=120, maxx=280, miny=-10, maxy=10)
# 10°S-10°N and 120°E-80°W
axs[0][0].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='dimgrey', lw=2.)

# ---

axs[0][1].pcolormesh(lons, lats, ds_sstk["wr1_cesm"].values,
                     transform=ccrs.PlateCarree(),
                     vmin=vmin, vmax=vmax, cmap='seismic')

axs[0][1].contourf(lons, lats, np.where((
    ds_sstk["wr1_cesm"].values <= ds_sstk['wr1_cesm_005'].values) | (
    ds_sstk["wr1_cesm"].values >= ds_sstk['wr1_cesm_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[0][1].set_extent([20, 340, -30, 70], crs=ccrs.PlateCarree())

axs[0][1].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[0][1].add_feature(cfeature.LAND, color='k', zorder=100)
axs[0][1].set_title('b) WR1: Alaskan Ridge (CESM2)', fontsize=12)
axs[0][1].margins(x=0, y=0)

gl = axs[0][1].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

geom = geometry.box(minx=120, maxx=280, miny=-10, maxy=10)

axs[0][1].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='dimgrey', lw=2.)

# ---

axs[1][0].pcolormesh(lons, lats, ds_sstk["wr2_era5"].values, 
                     transform=ccrs.PlateCarree(), 
                     vmin=vmin, vmax=vmax, cmap='seismic')

axs[1][0].contourf(lons, lats, np.where((
    ds_sstk["wr2_era5"].values <= ds_sstk['wr2_era5_005'].values) | (
    ds_sstk["wr2_era5"].values >= ds_sstk['wr2_era5_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[1][0].set_extent([20, 340, -30, 70], crs=ccrs.PlateCarree())

axs[1][0].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[1][0].add_feature(cfeature.LAND, color='k', zorder=100)
axs[1][0].set_title('c) WR2: Greenland High (ERA5)', fontsize=12)
axs[1][0].margins(x=0, y=0)

gl = axs[1][0].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

geom = geometry.box(minx=120, maxx=280, miny=-10, maxy=10)

axs[1][0].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='dimgrey', lw=2.)

# ---

axs[1][1].pcolormesh(lons, lats, ds_sstk["wr2_cesm"].values,
                     transform=ccrs.PlateCarree(),
                     vmin=vmin, vmax=vmax, cmap='seismic')

axs[1][1].contourf(lons, lats, np.where((
    ds_sstk["wr2_cesm"].values <= ds_sstk['wr2_cesm_005'].values) | (
    ds_sstk["wr2_cesm"].values >= ds_sstk['wr2_cesm_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[1][1].set_extent([20, 340, -30, 70], crs=ccrs.PlateCarree())

axs[1][1].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[1][1].add_feature(cfeature.LAND, color='k', zorder=100)
axs[1][1].set_title('d) WR2: Greenland High (CESM2)', fontsize=12)
axs[1][1].margins(x=0, y=0)

gl = axs[1][1].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

geom = geometry.box(minx=120, maxx=280, miny=-10, maxy=10)

axs[1][1].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='dimgrey', lw=2.)

# ---

axs[2][0].pcolormesh(lons, lats, ds_sstk["wr3_era5"].values,
                     transform=ccrs.PlateCarree(),
                     vmin=vmin, vmax=vmax, cmap='seismic')

axs[2][0].contourf(lons, lats, np.where((
    ds_sstk["wr3_era5"].values <= ds_sstk['wr3_era5_005'].values) | (
    ds_sstk["wr3_era5"].values >= ds_sstk['wr3_era5_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[2][0].set_extent([20, 340, -30, 70], crs=ccrs.PlateCarree())

axs[2][0].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[2][0].add_feature(cfeature.LAND, color='k', zorder=100)
axs[2][0].set_title('e) WR3: Pacific Trough (ERA5)', fontsize=12)
axs[2][0].margins(x=0, y=0)

gl = axs[2][0].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

geom = geometry.box(minx=120, maxx=280, miny=-10, maxy=10)

axs[2][0].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='dimgrey', lw=2.)

# ---

axs[2][1].pcolormesh(lons, lats, ds_sstk["wr3_cesm"].values,
                     transform=ccrs.PlateCarree(),
                     vmin=vmin, vmax=vmax, cmap='seismic')

axs[2][1].contourf(lons, lats, np.where((
    ds_sstk["wr3_cesm"].values <= ds_sstk['wr3_cesm_005'].values) | (
    ds_sstk["wr3_cesm"].values >= ds_sstk['wr3_cesm_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[2][1].set_extent([20, 340, -30, 70], crs=ccrs.PlateCarree())

axs[2][1].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[2][1].add_feature(cfeature.LAND, color='k', zorder=100)
axs[2][1].set_title('f) WR3: Pacific Trough (CESM2)', fontsize=12)
axs[2][1].margins(x=0, y=0)

gl = axs[2][1].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

geom = geometry.box(minx=120, maxx=280, miny=-10, maxy=10)

axs[2][1].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='dimgrey', lw=2.)

# ---

axs[3][0].pcolormesh(lons, lats, ds_sstk["wr4_era5"].values,
                     transform=ccrs.PlateCarree(),
                     vmin=vmin, vmax=vmax, cmap='seismic')

axs[3][0].contourf(lons, lats, np.where((
    ds_sstk["wr4_era5"].values <= ds_sstk['wr4_era5_005'].values) | (
    ds_sstk["wr4_era5"].values >= ds_sstk['wr4_era5_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[3][0].set_extent([20, 340, -30, 70], crs=ccrs.PlateCarree())

axs[3][0].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[3][0].add_feature(cfeature.LAND, color='k', zorder=100)
axs[3][0].set_title(
    'g) WR4: West Coast High (ERA5)', fontsize=12)
axs[3][0].margins(x=0, y=0)

gl = axs[3][0].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

geom = geometry.box(minx=120, maxx=280, miny=-10, maxy=10)

axs[3][0].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='dimgrey', lw=2.)

# ---

axs[3][1].pcolormesh(lons, lats, ds_sstk["wr4_cesm"].values,
                     transform=ccrs.PlateCarree(),
                     vmin=vmin, vmax=vmax, cmap='seismic')

axs[3][1].contourf(lons, lats, np.where((
    ds_sstk["wr4_cesm"].values <= ds_sstk['wr4_cesm_005'].values) | (
    ds_sstk["wr4_cesm"].values >= ds_sstk['wr4_cesm_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[3][1].set_extent([20, 340, -30, 70], crs=ccrs.PlateCarree())

axs[3][1].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[3][1].add_feature(cfeature.LAND, color='k', zorder=100)
axs[3][1].set_title('h) WR4: West Coast High (CESM2)', fontsize=12)
axs[3][1].margins(x=0, y=0)

gl = axs[3][1].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

geom = geometry.box(minx=120, maxx=280, miny=-10, maxy=10)

axs[3][1].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='dimgrey', lw=2.)

# ---

cbar_ax = fig.add_axes([0.25, -0.01, 0.5, 0.015])

ticks_1 = [-0.5, -0.25, 0, 0.25, 0.5]
cbar = fig.colorbar(pm, cax=cbar_ax, ticks=ticks_1[:], 
                    orientation='horizontal', extend='both')

cbar.ax.tick_params(labelsize=12)
cbar.set_label(u'Weeks 1-2 SST ($^{\circ}$C)', fontsize=12)

# --

plt.tight_layout()
plt.savefig("fig_wk12_sst.png", bbox_inches='tight', dpi=500)
plt.show()

# ---
# Out:
# /glade/scratch/molina/ipykernel_17828/1248245349.py:299: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# ## open data

# %%
ds_rlut = xr.open_dataset(
    '/glade/scratch/molina/s2s/bootstrap/rlut_week56_wxregimes.nc')
ds_sstk = xr.open_dataset(
    '/glade/scratch/molina/s2s/bootstrap/sstk_week56_wxregimes.nc')

# %% [markdown]
# ## Supplementary Figure 7

# %%
vmin = -5
vmax = 5

proj = ccrs.PlateCarree(central_longitude=180.0)

lons, lats = np.meshgrid(ds_rlut.lon, ds_rlut.lat)

# ---

fig, axs = plt.subplots(
    4, 2, subplot_kw=dict(projection=proj), figsize=(11, 8))

# ---

pm = axs[0][0].pcolormesh(lons, lats, -ds_rlut["wr1_era5"].values,
                          transform=ccrs.PlateCarree(),
                          vmin=vmin, vmax=vmax, cmap='BrBG_r')

axs[0][0].contourf(lons, lats, np.where((
    -ds_rlut["wr1_era5"].values >= -ds_rlut['wr1_era5_005'].values) | (
    -ds_rlut["wr1_era5"].values <= -ds_rlut['wr1_era5_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[0][0].set_extent([20, 340, -50, 50], crs=ccrs.PlateCarree())

axs[0][0].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[0][0].set_title(
    'a) WR1: Alaskan Ridge (ERA5)', fontsize=12)
axs[0][0].margins(x=0, y=0)

geom = geometry.box(minx=30, maxx=210, miny=-10, maxy=10)

axs[0][0].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='k', lw=2)

geom = geometry.box(minx=170-360, maxx=250-360, miny=10, maxy=48)

axs[0][0].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='b', lw=2)

gl = axs[0][0].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

# ---

axs[0][1].pcolormesh(lons, lats, ds_rlut["wr1_cesm"].values,
                     transform=ccrs.PlateCarree(), 
                     vmin=vmin, vmax=vmax, cmap='BrBG_r')

axs[0][1].contourf(lons, lats, np.where((
    ds_rlut["wr1_cesm"].values <= ds_rlut['wr1_cesm_005'].values) | (
    ds_rlut["wr1_cesm"].values >= ds_rlut['wr1_cesm_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[0][1].set_extent([20, 340, -50, 50], crs=ccrs.PlateCarree())

axs[0][1].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[0][1].set_title(
    'b) WR1: Alaskan Ridge (CESM2)', fontsize=12)
axs[0][1].margins(x=0, y=0)

geom = geometry.box(minx=30, maxx=210, miny=-10, maxy=10)

axs[0][1].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='k', lw=2)

geom = geometry.box(minx=170-360, maxx=250-360, miny=10, maxy=48)

axs[0][1].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='b', lw=2)

gl = axs[0][1].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

# ---

axs[1][0].pcolormesh(lons, lats, -ds_rlut["wr2_era5"].values,
                     transform=ccrs.PlateCarree(),
                     vmin=vmin, vmax=vmax, cmap='BrBG_r')

axs[1][0].contourf(lons, lats, np.where((
    -ds_rlut["wr2_era5"].values >= -ds_rlut['wr2_era5_005'].values) | (
    -ds_rlut["wr2_era5"].values <= -ds_rlut['wr2_era5_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[1][0].set_extent([20, 340, -50, 50], crs=ccrs.PlateCarree())

axs[1][0].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[1][0].set_title(
    'c) WR2: Greenland High (ERA5)', fontsize=12)
axs[1][0].margins(x=0, y=0)

geom = geometry.box(minx=30, maxx=210, miny=-10, maxy=10)

axs[1][0].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='k', lw=2)

geom = geometry.box(minx=170-360, maxx=250-360, miny=10, maxy=48)

axs[1][0].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='b', lw=2)

gl = axs[1][0].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

# ---

axs[1][1].pcolormesh(lons, lats, ds_rlut["wr2_cesm"].values,
                     transform=ccrs.PlateCarree(),
                     vmin=vmin, vmax=vmax, cmap='BrBG_r')

axs[1][1].contourf(lons, lats, np.where((
    ds_rlut["wr2_cesm"].values <= ds_rlut['wr2_cesm_005'].values) | (
    ds_rlut["wr2_cesm"].values >= ds_rlut['wr2_cesm_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[1][1].set_extent([20, 340, -50, 50], crs=ccrs.PlateCarree())

axs[1][1].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[1][1].set_title(
    'd) WR2: Greenland High (CESM2)', fontsize=12)
axs[1][1].margins(x=0, y=0)

geom = geometry.box(minx=30, maxx=210, miny=-10, maxy=10)

axs[1][1].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='k', lw=2)

geom = geometry.box(minx=170-360, maxx=250-360, miny=10, maxy=48)

axs[1][1].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='b', lw=2)

gl = axs[1][1].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

# ---

axs[2][0].pcolormesh(lons, lats, -ds_rlut["wr3_era5"].values,
                     transform=ccrs.PlateCarree(), 
                     vmin=vmin, vmax=vmax, cmap='BrBG_r')

axs[2][0].contourf(lons, lats, np.where((
    -ds_rlut["wr3_era5"].values >= -ds_rlut['wr3_era5_005'].values) | (
    -ds_rlut["wr3_era5"].values <= -ds_rlut['wr3_era5_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[2][0].set_extent([20, 340, -50, 50], crs=ccrs.PlateCarree())

axs[2][0].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[2][0].set_title(
    'e) WR3: Pacific Trough (ERA5)', fontsize=12)
axs[2][0].margins(x=0, y=0)

geom = geometry.box(minx=30, maxx=210, miny=-10, maxy=10)

axs[2][0].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='k', lw=2)

geom = geometry.box(minx=170-360, maxx=250-360, miny=10, maxy=48)

axs[2][0].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='b', lw=2)

gl = axs[2][0].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

# ---

axs[2][1].pcolormesh(lons, lats, ds_rlut["wr3_cesm"].values,
                     transform=ccrs.PlateCarree(),
                     vmin=vmin, vmax=vmax, cmap='BrBG_r')

axs[2][1].contourf(lons, lats, np.where((
    ds_rlut["wr3_cesm"].values <= ds_rlut['wr3_cesm_005'].values) | (
    ds_rlut["wr3_cesm"].values >= ds_rlut['wr3_cesm_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[2][1].set_extent([20, 340, -50, 50], crs=ccrs.PlateCarree())

axs[2][1].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[2][1].set_title(
    'f) WR3: Pacific Trough (CESM2)', fontsize=12)
axs[2][1].margins(x=0, y=0)

geom = geometry.box(minx=30, maxx=210, miny=-10, maxy=10)

axs[2][1].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='k', lw=2)

geom = geometry.box(minx=170-360, maxx=250-360, miny=10, maxy=48)

axs[2][1].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='b', lw=2)

gl = axs[2][1].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

# ---

axs[3][0].pcolormesh(lons, lats, -ds_rlut["wr4_era5"].values,
                     transform=ccrs.PlateCarree(),
                     vmin=vmin, vmax=vmax, cmap='BrBG_r')

axs[3][0].contourf(lons, lats, np.where((
    -ds_rlut["wr4_era5"].values >= -ds_rlut['wr4_era5_005'].values) | (
    -ds_rlut["wr4_era5"].values <= -ds_rlut['wr4_era5_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[3][0].set_extent([20, 340, -50, 50], crs=ccrs.PlateCarree())

axs[3][0].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[3][0].set_title(
    'g) WR4: West Coast High (ERA5)', fontsize=12)
axs[3][0].margins(x=0,y=0)

geom = geometry.box(minx=30, maxx=210, miny=-10, maxy=10)

axs[3][0].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='k', lw=2)

geom = geometry.box(minx=170-360, maxx=250-360, miny=10, maxy=48)

axs[3][0].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='b', lw=2)

gl = axs[3][0].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

# ---

axs[3][1].pcolormesh(lons, lats, ds_rlut["wr4_cesm"].values,
                     transform=ccrs.PlateCarree(),
                     vmin=vmin, vmax=vmax, cmap='BrBG_r')

axs[3][1].contourf(lons, lats, np.where((
    ds_rlut["wr4_cesm"].values <= ds_rlut['wr4_cesm_005'].values) | (
    ds_rlut["wr4_cesm"].values >= ds_rlut['wr4_cesm_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[3][1].set_extent([20, 340, -50, 50], crs=ccrs.PlateCarree())

axs[3][1].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[3][1].set_title(
    'h) WR4: West Coast High (CESM2)', fontsize=12)
axs[3][1].margins(x=0, y=0)

geom = geometry.box(minx=30, maxx=210, miny=-10, maxy=10)

axs[3][1].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='k', lw=2)

geom = geometry.box(minx=170-360, maxx=250-360, miny=10, maxy=48)

axs[3][1].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='b', lw=2)

gl = axs[3][1].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

# ---

cbar_ax = fig.add_axes([0.25, -0.01, 0.5, 0.015])

ticks_1 = [-4, -2, 0, 2, 4]
cbar = fig.colorbar(pm, cax=cbar_ax, ticks=ticks_1[:], 
                    orientation='horizontal', extend='both')

cbar.ax.tick_params(labelsize=12)
cbar.set_label(u'Weeks 5-6 Outgoing Longwave Radiation (W m$^{-2}$)', fontsize=12)

# --

plt.tight_layout()
plt.savefig("fig_wk56_olr.png", bbox_inches='tight', dpi=500)
plt.show()

# ---
# Out:
# /glade/scratch/molina/ipykernel_17828/3243419627.py:338: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# ## Supplementary Figure 8

# %%
vmin = -0.5
vmax = 0.5

proj = ccrs.PlateCarree(central_longitude=180.0)

lons, lats = np.meshgrid(ds_sstk.lon, ds_sstk.lat)

# ---

fig, axs = plt.subplots(
    4, 2, subplot_kw=dict(projection=proj), figsize=(11, 8))

# ---

pm = axs[0][0].pcolormesh(lons, lats, ds_sstk["wr1_era5"].values,
                          transform=ccrs.PlateCarree(),
                          vmin=vmin, vmax=vmax, cmap='seismic')

axs[0][0].contourf(lons, lats, np.where((
    ds_sstk["wr1_era5"].values <= ds_sstk['wr1_era5_005'].values) | (
    ds_sstk["wr1_era5"].values >= ds_sstk['wr1_era5_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[0][0].set_extent([20, 340, -30, 70], crs=ccrs.PlateCarree())

axs[0][0].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[0][0].add_feature(cfeature.LAND, color='k', zorder=100)
axs[0][0].set_title('a) WR1: Alaskan Ridge (ERA5)', fontsize=12)
axs[0][0].margins(x=0, y=0)

gl = axs[0][0].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

geom = geometry.box(minx=120, maxx=280, miny=-10, maxy=10)
# 10°S-10°N and 120°E-80°W
axs[0][0].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='dimgrey', lw=2.)

# ---

axs[0][1].pcolormesh(lons, lats, ds_sstk["wr1_cesm"].values,
                     transform=ccrs.PlateCarree(),
                     vmin=vmin, vmax=vmax, cmap='seismic')

axs[0][1].contourf(lons, lats, np.where((
    ds_sstk["wr1_cesm"].values <= ds_sstk['wr1_cesm_005'].values) | (
    ds_sstk["wr1_cesm"].values >= ds_sstk['wr1_cesm_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[0][1].set_extent([20, 340, -30, 70], crs=ccrs.PlateCarree())

axs[0][1].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[0][1].add_feature(cfeature.LAND, color='k', zorder=100)
axs[0][1].set_title('b) WR1: Alaskan Ridge (CESM2)', fontsize=12)
axs[0][1].margins(x=0, y=0)

gl = axs[0][1].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

geom = geometry.box(minx=120, maxx=280, miny=-10, maxy=10)

axs[0][1].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='dimgrey', lw=2.)

# ---

axs[1][0].pcolormesh(lons, lats, ds_sstk["wr2_era5"].values, 
                     transform=ccrs.PlateCarree(), 
                     vmin=vmin, vmax=vmax, cmap='seismic')

axs[1][0].contourf(lons, lats, np.where((
    ds_sstk["wr2_era5"].values <= ds_sstk['wr2_era5_005'].values) | (
    ds_sstk["wr2_era5"].values >= ds_sstk['wr2_era5_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[1][0].set_extent([20, 340, -30, 70], crs=ccrs.PlateCarree())

axs[1][0].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[1][0].add_feature(cfeature.LAND, color='k', zorder=100)
axs[1][0].set_title('c) WR2: Greenland High (ERA5)', fontsize=12)
axs[1][0].margins(x=0, y=0)

gl = axs[1][0].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

geom = geometry.box(minx=120, maxx=280, miny=-10, maxy=10)

axs[1][0].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='dimgrey', lw=2.)

# ---

axs[1][1].pcolormesh(lons, lats, ds_sstk["wr2_cesm"].values,
                     transform=ccrs.PlateCarree(),
                     vmin=vmin, vmax=vmax, cmap='seismic')

axs[1][1].contourf(lons, lats, np.where((
    ds_sstk["wr2_cesm"].values <= ds_sstk['wr2_cesm_005'].values) | (
    ds_sstk["wr2_cesm"].values >= ds_sstk['wr2_cesm_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[1][1].set_extent([20, 340, -30, 70], crs=ccrs.PlateCarree())

axs[1][1].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[1][1].add_feature(cfeature.LAND, color='k', zorder=100)
axs[1][1].set_title('d) WR2: Greenland High (CESM2)', fontsize=12)
axs[1][1].margins(x=0, y=0)

gl = axs[1][1].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

geom = geometry.box(minx=120, maxx=280, miny=-10, maxy=10)

axs[1][1].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='dimgrey', lw=2.)

# ---

axs[2][0].pcolormesh(lons, lats, ds_sstk["wr3_era5"].values,
                     transform=ccrs.PlateCarree(),
                     vmin=vmin, vmax=vmax, cmap='seismic')

axs[2][0].contourf(lons, lats, np.where((
    ds_sstk["wr3_era5"].values <= ds_sstk['wr3_era5_005'].values) | (
    ds_sstk["wr3_era5"].values >= ds_sstk['wr3_era5_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[2][0].set_extent([20, 340, -30, 70], crs=ccrs.PlateCarree())

axs[2][0].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[2][0].add_feature(cfeature.LAND, color='k', zorder=100)
axs[2][0].set_title('e) WR3: Pacific Trough (ERA5)', fontsize=12)
axs[2][0].margins(x=0, y=0)

gl = axs[2][0].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

geom = geometry.box(minx=120, maxx=280, miny=-10, maxy=10)

axs[2][0].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='dimgrey', lw=2.)

# ---

axs[2][1].pcolormesh(lons, lats, ds_sstk["wr3_cesm"].values,
                     transform=ccrs.PlateCarree(),
                     vmin=vmin, vmax=vmax, cmap='seismic')

axs[2][1].contourf(lons, lats, np.where((
    ds_sstk["wr3_cesm"].values <= ds_sstk['wr3_cesm_005'].values) | (
    ds_sstk["wr3_cesm"].values >= ds_sstk['wr3_cesm_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[2][1].set_extent([20, 340, -30, 70], crs=ccrs.PlateCarree())

axs[2][1].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[2][1].add_feature(cfeature.LAND, color='k', zorder=100)
axs[2][1].set_title('f) WR3: Pacific Trough (CESM2)', fontsize=12)
axs[2][1].margins(x=0, y=0)

gl = axs[2][1].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

geom = geometry.box(minx=120, maxx=280, miny=-10, maxy=10)

axs[2][1].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='dimgrey', lw=2.)

# ---

axs[3][0].pcolormesh(lons, lats, ds_sstk["wr4_era5"].values,
                     transform=ccrs.PlateCarree(),
                     vmin=vmin, vmax=vmax, cmap='seismic')

axs[3][0].contourf(lons, lats, np.where((
    ds_sstk["wr4_era5"].values <= ds_sstk['wr4_era5_005'].values) | (
    ds_sstk["wr4_era5"].values >= ds_sstk['wr4_era5_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[3][0].set_extent([20, 340, -30, 70], crs=ccrs.PlateCarree())

axs[3][0].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[3][0].add_feature(cfeature.LAND, color='k', zorder=100)
axs[3][0].set_title(
    'g) WR4: West Coast High (ERA5)', fontsize=12)
axs[3][0].margins(x=0, y=0)

gl = axs[3][0].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

geom = geometry.box(minx=120, maxx=280, miny=-10, maxy=10)

axs[3][0].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='dimgrey', lw=2.)

# ---

axs[3][1].pcolormesh(lons, lats, ds_sstk["wr4_cesm"].values,
                     transform=ccrs.PlateCarree(),
                     vmin=vmin, vmax=vmax, cmap='seismic')

axs[3][1].contourf(lons, lats, np.where((
    ds_sstk["wr4_cesm"].values <= ds_sstk['wr4_cesm_005'].values) | (
    ds_sstk["wr4_cesm"].values >= ds_sstk['wr4_cesm_995'].values),
         1., np.nan),
                   transform=ccrs.PlateCarree(), colors='none',
                   hatches=['//'], zorder=100)

axs[3][1].set_extent([20, 340, -30, 70], crs=ccrs.PlateCarree())

axs[3][1].coastlines(
    resolution='110m', facecolor='none', color='k', linewidth=0.5, zorder=10)
axs[3][1].add_feature(cfeature.LAND, color='k', zorder=100)
axs[3][1].set_title('h) WR4: West Coast High (CESM2)', fontsize=12)
axs[3][1].margins(x=0, y=0)

gl = axs[3][1].gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                         linewidth=0., color='none')
gl.top_labels = False
gl.right_labels = False
gl.xlines = False
gl.xlabel_style = {'size': 9, 'color': 'k'}
gl.ylabel_style = {'size': 9, 'color': 'k'}

geom = geometry.box(minx=120, maxx=280, miny=-10, maxy=10)

axs[3][1].add_geometries([geom], crs=cartopy.crs.PlateCarree(),
                         facecolor='none', edgecolor='dimgrey', lw=2.)

# ---

cbar_ax = fig.add_axes([0.25, -0.01, 0.5, 0.015])

ticks_1 = [-0.5, -0.25, 0, 0.25, 0.5]
cbar = fig.colorbar(pm, cax=cbar_ax, ticks=ticks_1[:], 
                    orientation='horizontal', extend='both')

cbar.ax.tick_params(labelsize=12)
cbar.set_label(u'Weeks 5-6 SST ($^{\circ}$C)', fontsize=12)

# --

plt.tight_layout()
plt.savefig("fig_wk56_sst.png", bbox_inches='tight', dpi=500)
plt.show()

# ---
# Out:
# /glade/scratch/molina/ipykernel_17828/2233949047.py:299: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
